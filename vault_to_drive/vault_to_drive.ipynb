# %% [markdown]
# # Google Vault export → Google Drive
#
# This notebook copies a Vault export straight into a Google Drive folder. It runs on Google's computer (Colab), so nothing is saved to your laptop.
#
# **Before you start**, finish **Part A** in the README (make a Google Cloud project, enable the 3 APIs, and download `client_secret.json`). Then run the cells below in order, top to bottom.

# %% [markdown]
# ## Step 1 — Install the helper libraries
# Press the ▶ play button on the left of this cell and wait for it to finish.

# %%
# !pip install -q google-api-python-client google-auth google-auth-oauthlib google-auth-httplib2
print('Libraries installed. Go to Step 2.')

# %% [markdown]
# ## Step 2 — Upload your files
# Run this cell, then click **Choose Files** and upload BOTH:
# - `client_secret.json` (your ID badge from the README)
# - `vault_to_drive.py` (the program, from this folder)

# %%
from google.colab import files
files.upload()

# %% [markdown]
# ## Step 3 — Enter your details
# Paste your Vault matter ID (from the vault.google.com web address) and a name for the Drive folder. The matter ID below is already filled in for you; change it if you need a different matter.

# %%
MATTER_ID = "3cf11af8-e562-40a7-af21-0de0dd0db91a"  #@param {type:"string"}
DRIVE_FOLDER = "Vault Export"  #@param {type:"string"}
print('Matter:', MATTER_ID)
print('Drive folder:', DRIVE_FOLDER)

# %% [markdown]
# ## Step 4 — Run the transfer
# Run this cell. The first time, it shows a sign-in link: click it, choose your Google account, and allow the permissions (paste the code back here if asked). Then type the **number** of the export you want and press Enter.
#
# When it says **All done!**, open Google Drive and look for your folder.

# %%
# !python vault_to_drive.py --matter-id "$MATTER_ID" --drive-folder "$DRIVE_FOLDER"
